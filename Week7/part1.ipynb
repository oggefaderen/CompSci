# %%
import nltk
nltk.download('book')
from nltk.book import *
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/oskarkarlsson/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/oskarkarlsson/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/oskarkarlsson/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/oskarkarlsson/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/oskarkarlsson/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/oskarkarlsson/nltk_data...
# ...

# %%
# exercise 1
print(f'Ex1: 12/(4+1) = {12/(4+1)}')

# exercise 2
print(f'Ex2: Amount of hundred letter strings: {26**100}')

# exercise 3
res = ['Monty', 'Python'] * 20
print(f'Ex3: Here is what happends when you multiply a list: {res}')

# exercise 4
res = len(text2)
print(f'Ex4: The amount of words in text2 is: {res}')
# Out:
# Ex1: 12/(4+1) = 2.4
# Ex2: Amount of hundred letter strings: 3142930641582938830174357788501626427282669988762475256374173175398995908420104023465432599069702289330964075081611719197835869803511992549376
# Ex3: Here is what happends when you multiply a list: ['Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python']
# Ex4: The amount of words in text2 is: 141576

# %%
# exercise 5
# Assessing Table 1.1, humor has a larger lexical diversity than romance

# %%
# exercise 6
# dispersion plot for protagonists in Sense and Sensibility (text2)
fdist = FreqDist(text2)
text2.dispersion_plot(['Elinor', 'Marianne', 'Edward', 'Willoughby'])

# %% [markdown]
# Elinor and Marianne are the most mentioned characters, indicating that the main roles are played by females (they are probably protagonists). Willoughby appear more alongside Marianne - more visible in the interval 80000-110000. They are probably the couple.

# %%
# exercise 7
# find collocations in text5
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# exercise 8
#
# Purpose of this expression: len(set(text4)). Amount of unique words. set removes the duplicate words, and len counts the amount.

# %%
# exercise 9
my_string = 'this is a string about a string that is a string'
# a)
my_string
# Out:
# 'this is a string about a string that is a string'

# %%
print(my_string)
# Out:
# this is a string about a string that is a string

# %%
# b)
new_my_string = my_string + my_string
new_my_string

# How can i fix the missing space?
# I can add a space at the end of the string or simply also add a space
# Out:
# 'this is a string about a string that is a stringthis is a string about a string that is a string'

# %%
# exercise 10
hello_friend = ['hello', 'friend']

# a)
as_string = ' '.join(hello_friend)
print(as_string)

# b)
split = as_string.split()
print(split)
# Out:
# hello friend
# ['hello', 'friend']

# %%
# exercise 11
phrase1 = ['the', 'cat', 'sat']
phrase2 = ['on', 'the', 'mat']

combined1 = phrase1 + phrase2
combined2 = phrase2 + phrase1

len_1_2 = len(phrase1) + len(phrase2)
len_1_2_mod = len(phrase1+phrase2)

print(f'Length of phrase1 and phrase2 added together: {len_1_2}')
print(f'Length of phrase1 and phrase2 added together inside function: {len_1_2_mod}')

# There is no difference between the two lengths
# Out:
# Length of phrase1 and phrase2 added together: 6
# Length of phrase1 and phrase2 added together inside function: 6

# %%
# exercise 12
# b. is more effective in NLP as we work with words rather than letters

# %%
# exercise 13
# it retrieves the second index of the list and the third letter in that list item
sent1[2][2]
# Out:
# 'h'

# %%
# exercise 14
# indexes of 'the' in sent3: 1, 5, 8
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
# exercise 15
text5
res = sorted(set([w for w in text5 if w.startswith('b')]))
res
# Out:
# ['b',
#  'b-day',
#  'b/c',
#  'b4',
#  'babay',
#  'babble',
#  'babblein',
#  'babe',
#  'babes',
#  'babi',
#  'babies',
#  'babiess',
#  'baby',
#  'babycakeses',
#  'bachelorette',
#  'back',
#  'backatchya',
#  'backfrontsidewaysandallaroundtheworld',
#  'backroom',
#  'backup',
#  'bacl',
#  'bad',
#  'bag',
#  'bagel',
#  'bagels',
#  'bahahahaa',
#  'bak',
#  'baked',
#  'balad',
#  'balance',
#  'balck',
#  'ball',
#  'ballin',
#  'balls',
#  'ban',
#  'band',
#  'bandito',
#  'bandsaw',
#  'banjoes',
#  'banned',
#  'baord',
#  'bar',
#  'barbie',
#  'bare',
#  'barely',
#  'bares',
#  'barfights',
#  'barks',
#  'barn',
#  'barrel',
#  'base',
#  'bases',
#  'basically',
#  'basket',
#  'battery',
#  'bay',
#  'bbbbbyyyyyyyeeeeeeeee',
#  'bbiam',
#  'bbl',
#  'bbs',
#  'bc',
#  'be',
#  'beach',
#  'beachhhh',
#  'beam',
#  'beams',
#  'beanbag',
#  'beans',
#  'bear',
#  'bears',
#  'beat',
#  'beaten',
#  'beatles',
#  'beats',
#  'beattles',
#  'beautiful',
# ...
